# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz,plot_tree
# !pip install image
from IPython.display import Image

# %%
 df =pd.read_csv("/content/demoDT.csv",sep=",")
print(df)
# Out:
#    State  Literacy   Cleanliness   Crime_Rate  Good
# 0      A        92            90           54     0
# 1      B        56            67           50     1
# 2      C        78            80           62     0
# 3      D        85            75           48     1
# 4      E        60            82           55     0
# 5      F        72            78           60     0
# 6      G        88            85           45     0
# 7      H        64            70           58     1
# 8      I        90            88           42     0
# 9      J        68            72           65     1
# 10     K        75            79           57     0
# 11     L        82            86           49     1
# 12     M        58            65           63     0
# 13     N        77            76           52     1
# 14     O        94            91           40     0
# 15     P        63            74           61     1
# 16     Q        79            83           47     1
# 17     R        71            68           59     1
# 18     S        86            89           43     1
# 19     T        66            71           64     1
# 20     U        81            81           51     1
# 21     V        70            77           56     1
# 22     W        87            84           46     1
# 23     X        62            69           66     0
# 24     Y        76            73           53     0
# 25     Z        83            87           44     0

# %%
feature_cols=['Literacy','Good',' Crime_Rate']
feature=df[feature_cols]#features
Target=df.Good#target variable

# %%
#Create Decision Tree classifier object
DT=DecisionTreeClassifier()
#Train Decision Tree Classifier
DT=DT.fit(feature,Target)

# %%
#predict the response for test dataset
l=int(input("Enter Literacy: "))
cl=int(input("Enter Cleanliness: "))
cr=int(input("Enter CrimeRate: "))

pred=DT.predict([[l,cl,cr]])
if pred==1:
  print("Good State")
else:
  print("Bad State")
# Out:
# Enter Literacy: 92
# Enter Cleanliness: 90
# Enter CrimeRate: 54
# Good State
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
plot_tree(DT)#plot tree(trained model name)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 0.5\ngini = 0.497\nsamples = 26\nvalue = [12, 14]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]')]

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import  RandomForestClassifier

# %%
 df =pd.read_csv("/content/demoDT.csv",sep=",")
print(df)
# Out:
#    State  Literacy   Cleanliness   Crime_Rate  Good
# 0      A        92            90           54     0
# 1      B        56            67           50     1
# 2      C        78            80           62     0
# 3      D        85            75           48     1
# 4      E        60            82           55     0
# 5      F        72            78           60     0
# 6      G        88            85           45     0
# 7      H        64            70           58     1
# 8      I        90            88           42     0
# 9      J        68            72           65     1
# 10     K        75            79           57     0
# 11     L        82            86           49     1
# 12     M        58            65           63     0
# 13     N        77            76           52     1
# 14     O        94            91           40     0
# 15     P        63            74           61     1
# 16     Q        79            83           47     1
# 17     R        71            68           59     1
# 18     S        86            89           43     1
# 19     T        66            71           64     1
# 20     U        81            81           51     1
# 21     V        70            77           56     1
# 22     W        87            84           46     1
# 23     X        62            69           66     0
# 24     Y        76            73           53     0
# 25     Z        83            87           44     0

# %%
feature_cols=['Literacy','Good',' Crime_Rate']
feature=df[feature_cols]#features
Target=df.Good#target variable

# %%
#Create Decision Tree classifier object
RF=RandomForestClassifier(n_estimators=10)
#Train Decision Tree Classifier
RF=RF.fit(feature,Target)

# %%
#predict the response for test dataset
l=int(input("Enter Literacy: "))
cl=int(input("Enter Cleanliness: "))
cr=int(input("Enter CrimeRate: "))

pred=DT.predict([[l,cl,cr]])
if pred==1:
  print("Good State")
else:
  print("Bad State")
# Out:
# Enter Literacy: 92
# Enter Cleanliness: 90
# Enter CrimeRate: 54
# Good State
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
#saving all decision trees
import os
output_dir="tree_visualizations"
os.makedirs(output_dir,exist_ok=True)

# %%
RF.estimators_ #model name=RF
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=1508057584),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1068853947),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2090737156),
#  DecisionTreeClassifier(max_features='sqrt', random_state=266784468),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1108496449),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1353608575),
#  DecisionTreeClassifier(max_features='sqrt', random_state=916987072),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1962668072),
#  DecisionTreeClassifier(max_features='sqrt', random_state=810519466),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1954389181)]
